# %%
print("hello world")
# Out:
# hello world

# %%
players = {
    "Virat": [6, 2, 4, 0, 6, 1],
    "Rohit": [6, 1, 0, 2, 6, 4],
    "Dhoni": [6, 6, 2, 4, 6, 6]
}

# %%
for player,scores in players.items():
    print(player)
    # print(scores)
    players[player] = sum(scores)
    
#     print(player)
#     total_player_scores[player]=sum(players[player])
# print(total_player_scores)
# Out:
# Virat
# Rohit
# Dhoni

# %%
players
# Out:
# {'Virat': 19, 'Rohit': 19, 'Dhoni': 30}
